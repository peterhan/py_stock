# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import tushare as ts
import talib as ta
import pandas.util.testing as tm

# %%
tm.N=5
df = tm.makeTimeDataFrame()
np.asarray(df.columns).repeat(3)
np.tile(df.index,(3,1)).flatten()
# Out:
# array(['2000-01-03T00:00:00.000000000', '2000-01-04T00:00:00.000000000',
#        '2000-01-05T00:00:00.000000000', '2000-01-06T00:00:00.000000000',
#        '2000-01-07T00:00:00.000000000', '2000-01-03T00:00:00.000000000',
#        '2000-01-04T00:00:00.000000000', '2000-01-05T00:00:00.000000000',
#        '2000-01-06T00:00:00.000000000', '2000-01-07T00:00:00.000000000',
#        '2000-01-03T00:00:00.000000000', '2000-01-04T00:00:00.000000000',
#        '2000-01-05T00:00:00.000000000', '2000-01-06T00:00:00.000000000',
#        '2000-01-07T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
def unpivot(frame):
    N, K = frame.shape
    data = {'value': frame.to_numpy().ravel('F'),
            'variable': np.asarray(frame.columns).repeat(N),
            'date': np.tile(np.asarray(frame.index), K)}
    return pd.DataFrame(data, columns=['date', 'variable', 'value'])

ddf=tm.makeTimeDataFrame()
df = unpivot(ddf)
print ddf
# a=df.to_numpy()
# print a.ravel('C')
# print a.ravel('F')
# print a.ravel('A')
# print a.ravel('K')
df[df['variable']=='A']
# Out:
#                    A         B         C         D
# 2000-01-03 -1.166453 -0.608588 -0.570124 -1.420567
# 2000-01-04  0.734408 -0.243433  0.676961 -1.017439
# 2000-01-05 -0.588045 -0.364831  0.579969  1.960473
# 2000-01-06 -0.137850  0.333080  0.067906 -0.788586
# 2000-01-07  2.073478 -0.618658  0.735629 -1.310066
#         date variable     value
# 0 2000-01-03        A -1.166453
# 1 2000-01-04        A  0.734408
# 2 2000-01-05        A -0.588045
# 3 2000-01-06        A -0.137850
# 4 2000-01-07        A  2.073478

# %%
df.pivot(index='date',columns='variable',values='value')
# Out:
# variable           A         B         C         D
# date
# 2000-01-03 -1.166453 -0.608588 -0.570124 -1.420567
# 2000-01-04  0.734408 -0.243433  0.676961 -1.017439
# 2000-01-05 -0.588045 -0.364831  0.579969  1.960473
# 2000-01-06 -0.137850  0.333080  0.067906 -0.788586
# 2000-01-07  2.073478 -0.618658  0.735629 -1.310066

# %%
df['value2']=df['value']*2

# %%
pdf =df.pivot(index='date',columns='variable',values='value')

# %%
pdf.stack()
# Out:
# date        variable
# 2000-01-03  A          -1.166453
#             B          -0.608588
#             C          -0.570124
#             D          -1.420567
# 2000-01-04  A           0.734408
#             B          -0.243433
#             C           0.676961
#             D          -1.017439
# 2000-01-05  A          -0.588045
#             B          -0.364831
#             C           0.579969
#             D           1.960473
# 2000-01-06  A          -0.137850
#             B           0.333080
#             C           0.067906
#             D          -0.788586
# 2000-01-07  A           2.073478
#             B          -0.618658
#             C           0.735629
#             D          -1.310066
# dtype: float64

# %%
pdf.stack().unstack(0)
# Out:
# date      2000-01-03  2000-01-04  2000-01-05  2000-01-06  2000-01-07
# variable
# A          -1.166453    0.734408   -0.588045   -0.137850    2.073478
# B          -0.608588   -0.243433   -0.364831    0.333080   -0.618658
# C          -0.570124    0.676961    0.579969    0.067906    0.735629
# D          -1.420567   -1.017439    1.960473   -0.788586   -1.310066

# %%
columns = pd.MultiIndex.from_tuples([('A', 'cat'), ('B', 'dog'),
                                     ('B', 'cat'), ('A', 'dog')],
                                    names=['exp', 'animal'])


index = pd.MultiIndex.from_product([('bar', 'baz', 'foo', 'qux'),
                                    ('one', 'two')],
                                   names=['first', 'second'])


df = pd.DataFrame(np.random.randn(8, 4), index=index, columns=columns)

# %%
df
# Out:
# exp                  A         B                   A
# animal             cat       dog       cat       dog
# first second
# bar   one     1.194152  1.190003  0.284197  0.234990
#       two     1.570925  2.875092 -0.202166 -1.158233
# baz   one    -0.283158  0.715107  0.294382  0.388933
#       two     0.135877 -0.675227  0.338014 -0.002869
# foo   one    -1.543733  1.262670  1.144078 -0.598682
#       two     0.880649  1.605390  1.905638  1.195459
# qux   one    -0.870302  0.858279  1.103855 -0.408444
#       two     1.017530  1.337150 -1.238638  0.612551

# %%
df2 = df.iloc[[0, 1, 2, 4, 5, 7]]
print df2
# Out:
# exp                  A         B                   A
# animal             cat       dog       cat       dog
# first second
# bar   one     1.194152  1.190003  0.284197  0.234990
#       two     1.570925  2.875092 -0.202166 -1.158233
# baz   one    -0.283158  0.715107  0.294382  0.388933
# foo   one    -1.543733  1.262670  1.144078 -0.598682
#       two     0.880649  1.605390  1.905638  1.195459
# qux   two     1.017530  1.337150 -1.238638  0.612551

# %%
df2.stack(['exp','animal'])
# Out:
# first  second  exp  animal
# bar    one     A    cat       1.194152
#                     dog       0.234990
#                B    cat       0.284197
#                     dog       1.190003
#        two     A    cat       1.570925
#                     dog      -1.158233
#                B    cat      -0.202166
#                     dog       2.875092
# baz    one     A    cat      -0.283158
#                     dog       0.388933
#                B    cat       0.294382
#                     dog       0.715107
# foo    one     A    cat      -1.543733
#                     dog      -0.598682
#                B    cat       1.144078
#                     dog       1.262670
#        two     A    cat       0.880649
#                     dog       1.195459
#                B    cat       1.905638
#                     dog       1.605390
# qux    two     A    cat       1.017530
#                     dog       0.612551
#                B    cat      -1.238638
#                     dog       1.337150
# dtype: float64

# %%
df2.unstack(0)
df.stack()
# Out:
# exp                         A         B
# first second animal
# bar   one    cat     1.194152  0.284197
#              dog     0.234990  1.190003
#       two    cat     1.570925 -0.202166
#              dog    -1.158233  2.875092
# baz   one    cat    -0.283158  0.294382
#              dog     0.388933  0.715107
#       two    cat     0.135877  0.338014
#              dog    -0.002869 -0.675227
# foo   one    cat    -1.543733  1.144078
#              dog    -0.598682  1.262670
#       two    cat     0.880649  1.905638
#              dog     1.195459  1.605390
# qux   one    cat    -0.870302  1.103855
#              dog    -0.408444  0.858279
#       two    cat     1.017530 -1.238638
#              dog     0.612551  1.337150

# %%
df.columns
# Out:
# MultiIndex(levels=[[u'A', u'B'], [u'cat', u'dog']],
#            codes=[[0, 1, 1, 0], [0, 1, 0, 1]],
#            names=[u'exp', u'animal'])

# %%
df.groupby(level=1,axis=1).mean()
# Out:
# animal             cat       dog
# first second
# bar   one     0.739175  0.712497
#       two     0.684380  0.858429
# baz   one     0.005612  0.552020
#       two     0.236945 -0.339048
# foo   one    -0.199827  0.331994
#       two     1.393144  1.400424
# qux   one     0.116777  0.224917
#       two    -0.110554  0.974851

# %%
df = pd.read_csv("czk.mat.txt",delimiter="|")

# %%
# plt.scatter(df['pph'],df['sent'])
np.arange(15).reshape(3,5).data
# Out:
# <read-write buffer for 0x000000000E5F9DA0, size 60, offset 0 at 0x000000000E592BC8>

# %%
sdf=ts.get_k_data('600438')

# %%
sdf.columns
sdf.set_index('date')
# Out:
#               open   close    high     low     volume    code
# date
# 2017-01-12   6.049   6.039   6.088   6.010    57142.0  600438
# 2017-01-13   6.088   6.039   6.088   5.816   208629.0  600438
# 2017-01-16   6.010   6.127   6.166   5.835   322505.0  600438
# 2017-01-17   6.039   6.127   6.156   6.010    58487.0  600438
# 2017-01-18   6.146   6.029   6.146   6.010    55206.0  600438
# 2017-01-19   6.029   5.952   6.029   5.923    53740.0  600438
# 2017-01-20   5.961   6.020   6.039   5.913   103720.0  600438
# 2017-01-23   6.107   6.078   6.146   6.039    56145.0  600438
# 2017-01-24   6.078   6.010   6.098   5.991    58217.0  600438
# 2017-01-25   5.991   6.020   6.049   5.971    27080.0  600438
# 2017-01-26   6.020   6.059   6.068   6.020    32418.0  600438
# 2017-02-03   6.059   5.991   6.078   5.981    43256.0  600438
# 2017-02-06   6.020   6.039   6.059   5.991    70211.0  600438
# 2017-02-07   6.039   5.991   6.039   5.961    58430.0  600438
